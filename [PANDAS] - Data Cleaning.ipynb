# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
zara = pd.read_csv('zara.csv')

# %% [markdown]
# **Step 1:** Data Exploration
#
# **Step 2:** Handle Missing & Duplicated Values
#
# **Step 3:** Add / Drop Columns
#
# **Step 4:** Fix Data Types
# * String to Datetime
# * String to Numeric
# * Float to Int
# * String to Category
#
# **Step 5:** Fix and Make Formats Uniform
# * Removing Unnecessary Characters
# * Removing Unnecessary Spaces
# * Fixing Cases

# %% [markdown]
# ## **Step 1: Basic Data Exploration**
# We need to explore our data to understand its nature.

# %%
# To see the size of our data (total rows and columns)
zara.shape
# Out:
# (275, 12)

# %%
# To see how sample data looks like
zara.head(3)
# Out:
#    Product ID     Release Product Position section     terms  \
# 0    179801.0  10/21/2023   Front of Store     MAN   jackets
# 1    183243.0    7/1/2023   Front of Store     MAN   jackets
# 2    177771.0   1/22/2023          End-cap     MAN  t-shirts
#
#                 sku                               name  \
# 0   311307255-800-2  CONTRASTING PATCHES BOMBER JACKET
# 1  328250627-251-46                        SUIT JACKET
# 2   281883711-071-2                        SUIT JACKET
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
# 2  Jacket with lightly padded interior. Corduroy ...      Yes       Yes
#
#       price  Sales Volume
# 0  $169.00         2608.0
# 1  $169.00         1524.0
# 2   $69.90         1764.0

# %%
# To see summary of the DataFrame
# No. of columns, column labels, data types, memory usage, and the no. of non-null values
zara.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        261 non-null    float64
#  1   Release           261 non-null    object
#  2   Product Position  261 non-null    object
#  3   section           255 non-null    object
#  4   terms             261 non-null    object
#  5   sku               261 non-null    object
#  6   name              261 non-null    object
#  7   description       257 non-null    object
#  8   Seasonal          261 non-null    object
#  9   Promotion         261 non-null    object
#  10  price             261 non-null    object
#  11  Sales Volume      261 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 25.9+ KB

# %%
# To see number of null values
zara.isnull().sum()
# Out:
# Product ID          14
# Release             14
# Product Position    14
# section             20
# terms               14
# sku                 14
# name                14
# description         18
# Seasonal            14
# Promotion           14
# price               14
# Sales Volume        14
# dtype: int64

# %% [markdown]
# ## **Step 2: Handling Missing Values**
# When dealing with nulls... there are two options:
#
# 1. Get rid of the rows/columns with null (if other data will not be affected)
#
# But if removing it will result to a loss of a great chunk of data:
# 2. Fill it in with non-null values.

# %%
zara.isnull().sum().sum()
# Out:
# 178

# %%
zara.head(10)
# Out:
#    Product ID     Release Product Position section     terms  \
# 0    179801.0  10/21/2023   Front of Store     MAN   jackets
# 1    183243.0    7/1/2023   Front of Store     MAN   jackets
# 2    177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3    171860.0    1/4/2023            Aisle     NaN  t-shirts
# 4    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 6         NaN         NaN              NaN     NaN       NaN
# 7    178281.0    3/8/2024          End-cap     MAN   jackets
# 8    155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9    199233.0   1/15/2024            Aisle     MAN   jackets
#
#                 sku                                      name  \
# 0   311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1  328250627-251-46                               SUIT JACKET
# 2   281883711-071-2                               SUIT JACKET
# 3   323646471-802-2                       PADDED DENIM JACKET
# 4   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 6               NaN                                       NaN
# 7   315758723-401-2                             BOMBER JACKET
# 8   324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9   330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
# 2  Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3  Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 6                                                NaN      NaN       NaN
# 7  Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8  Wool and silk blend top. High collar and long ...       No       Yes
# 9  Oversized jacket. Notched lapel collar and lon...       No       Yes
#
#       price  Sales Volume
# 0  $169.00         2608.0
# 1  $169.00         1524.0
# 2   $69.90         1764.0
# 3  $109.00          707.0
# 4   $59.90         2877.0
# 5   $59.90         2877.0
# 6       NaN           NaN
# 7  $169.00         1145.0
# 8   $49.90         1942.0
# 9  $159.00         2222.0

# %% [markdown]
# Before we do actual changes, we first have to create a copy of our dataset so that we dont compromise our original raw data.

# %% [markdown]
# ### 1. Getting rid of rows/columns with null

# %%
df = zara.copy()

# %%
# Not like this
# df = zara

# %% [markdown]
# #### Why use `.copy()`

# %%
sample = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})

# %%
# Using .copy()
copy_sample = sample.copy()
copy_sample['A'] = [100, 200]
sample  # df remains unchanged.
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
ref_sample = sample
ref_sample['A'] = [10, 20]
sample  # df is also modified!
# Out:
#     A  B
# 0  10  3
# 1  20  4

# %%
zara.head(10)
# Out:
#    Product ID     Release Product Position section     terms  \
# 0    179801.0  10/21/2023   Front of Store     MAN   jackets
# 1    183243.0    7/1/2023   Front of Store     MAN   jackets
# 2    177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3    171860.0    1/4/2023            Aisle     NaN  t-shirts
# 4    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 6         NaN         NaN              NaN     NaN       NaN
# 7    178281.0    3/8/2024          End-cap     MAN   jackets
# 8    155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9    199233.0   1/15/2024            Aisle     MAN   jackets
#
#                 sku                                      name  \
# 0   311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1  328250627-251-46                               SUIT JACKET
# 2   281883711-071-2                               SUIT JACKET
# 3   323646471-802-2                       PADDED DENIM JACKET
# 4   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 6               NaN                                       NaN
# 7   315758723-401-2                             BOMBER JACKET
# 8   324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9   330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
# 2  Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3  Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 6                                                NaN      NaN       NaN
# 7  Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8  Wool and silk blend top. High collar and long ...       No       Yes
# 9  Oversized jacket. Notched lapel collar and lon...       No       Yes
#
#       price  Sales Volume
# 0  $169.00         2608.0
# 1  $169.00         1524.0
# 2   $69.90         1764.0
# 3  $109.00          707.0
# 4   $59.90         2877.0
# 5   $59.90         2877.0
# 6       NaN           NaN
# 7  $169.00         1145.0
# 8   $49.90         1942.0
# 9  $159.00         2222.0

# %%
# Getting rid of rows where all values are null
# This line does not really change the original df.
# Instead it returns to us a copy of the orig dataframe with the operation applied.
zara.dropna(how='all').head(10)
# Out:
#     Product ID     Release Product Position section     terms  \
# 0     179801.0  10/21/2023   Front of Store     MAN   jackets
# 1     183243.0    7/1/2023   Front of Store     MAN   jackets
# 2     177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3     171860.0    1/4/2023            Aisle     NaN  t-shirts
# 4     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 7     178281.0    3/8/2024          End-cap     MAN   jackets
# 8     155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9     199233.0   1/15/2024            Aisle     MAN   jackets
# 10    181502.0   11/7/2023   Front of Store   WOMAN  sweaters
#
#                  sku                                      name  \
# 0    311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1   328250627-251-46                               SUIT JACKET
# 2    281883711-071-2                               SUIT JACKET
# 3    323646471-802-2                       PADDED DENIM JACKET
# 4    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 7    315758723-401-2                             BOMBER JACKET
# 8    324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9    330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
# 10   323175653-803-2                        SOFT JEWEL SWEATER
#
#                                           description Seasonal Promotion  \
# 0   Varsity jacket with elastic collar and long sl...      Yes        No
# 1   Straight fit jacket made of dense stretch fabr...       No       Yes
# 2   Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3   Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 7   Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8   Wool and silk blend top. High collar and long ...       No       Yes
# 9   Oversized jacket. Notched lapel collar and lon...       No       Yes
# 10  Sweater made of soft touch fabric. Round neckl...       No       Yes
#
#        price  Sales Volume
# 0   $169.00         2608.0
# 1   $169.00         1524.0
# 2    $69.90         1764.0
# 3   $109.00          707.0
# 4    $59.90         2877.0
# 5    $59.90         2877.0
# 7   $169.00         1145.0
# 8    $49.90         1942.0
# 9   $159.00         2222.0
# 10   $39.90         2591.0

# %%
zara.head(10)
# Out:
#    Product ID     Release Product Position section     terms  \
# 0    179801.0  10/21/2023   Front of Store     MAN   jackets
# 1    183243.0    7/1/2023   Front of Store     MAN   jackets
# 2    177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3    171860.0    1/4/2023            Aisle     NaN  t-shirts
# 4    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 6         NaN         NaN              NaN     NaN       NaN
# 7    178281.0    3/8/2024          End-cap     MAN   jackets
# 8    155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9    199233.0   1/15/2024            Aisle     MAN   jackets
#
#                 sku                                      name  \
# 0   311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1  328250627-251-46                               SUIT JACKET
# 2   281883711-071-2                               SUIT JACKET
# 3   323646471-802-2                       PADDED DENIM JACKET
# 4   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 6               NaN                                       NaN
# 7   315758723-401-2                             BOMBER JACKET
# 8   324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9   330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
# 2  Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3  Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 6                                                NaN      NaN       NaN
# 7  Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8  Wool and silk blend top. High collar and long ...       No       Yes
# 9  Oversized jacket. Notched lapel collar and lon...       No       Yes
#
#       price  Sales Volume
# 0  $169.00         2608.0
# 1  $169.00         1524.0
# 2   $69.90         1764.0
# 3  $109.00          707.0
# 4   $59.90         2877.0
# 5   $59.90         2877.0
# 6       NaN           NaN
# 7  $169.00         1145.0
# 8   $49.90         1942.0
# 9  $159.00         2222.0

# %% [markdown]
# Cont.

# %%
df.isnull().sum()
# Out:
# Product ID          14
# Release             14
# Product Position    14
# section             20
# terms               14
# sku                 14
# name                14
# description         18
# Seasonal            14
# Promotion           14
# price               14
# Sales Volume        14
# dtype: int64

# %%
df.dropna().head(10)
# Out:
#     Product ID     Release Product Position section     terms  \
# 0     179801.0  10/21/2023   Front of Store     MAN   jackets
# 1     183243.0    7/1/2023   Front of Store     MAN   jackets
# 2     177771.0   1/22/2023          End-cap     MAN  t-shirts
# 4     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 7     178281.0    3/8/2024          End-cap     MAN   jackets
# 8     155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9     199233.0   1/15/2024            Aisle     MAN   jackets
# 10    181502.0   11/7/2023   Front of Store   WOMAN  sweaters
# 11    174708.0    3/5/2023   Front of Store     MAN  sweaters
#
#                  sku                                      name  \
# 0    311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1   328250627-251-46                               SUIT JACKET
# 2    281883711-071-2                               SUIT JACKET
# 4    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 7    315758723-401-2                             BOMBER JACKET
# 8    324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9    330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
# 10   323175653-803-2                        SOFT JEWEL SWEATER
# 11   317889153-700-3                 ABSTRACT JACQUARD SWEATER
#
#                                           description Seasonal Promotion  \
# 0   Varsity jacket with elastic collar and long sl...      Yes        No
# 1   Straight fit jacket made of dense stretch fabr...       No       Yes
# 2   Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 4   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 7   Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8   Wool and silk blend top. High collar and long ...       No       Yes
# 9   Oversized jacket. Notched lapel collar and lon...       No       Yes
# 10  Sweater made of soft touch fabric. Round neckl...       No       Yes
# 11  Full cut cotton knit sweater. Round neck and l...      Yes        No
#
#        price  Sales Volume
# 0   $169.00         2608.0
# 1   $169.00         1524.0
# 2    $69.90         1764.0
# 4    $59.90         2877.0
# 5    $59.90         2877.0
# 7   $169.00         1145.0
# 8    $49.90         1942.0
# 9   $159.00         2222.0
# 10   $39.90         2591.0
# 11   $59.90          529.0

# %%
df.dropna(how='all').head(10)
# Out:
#     Product ID     Release Product Position section     terms  \
# 0     179801.0  10/21/2023   Front of Store     MAN   jackets
# 1     183243.0    7/1/2023   Front of Store     MAN   jackets
# 2     177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3     171860.0    1/4/2023            Aisle     NaN  t-shirts
# 4     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 7     178281.0    3/8/2024          End-cap     MAN   jackets
# 8     155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9     199233.0   1/15/2024            Aisle     MAN   jackets
# 10    181502.0   11/7/2023   Front of Store   WOMAN  sweaters
#
#                  sku                                      name  \
# 0    311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1   328250627-251-46                               SUIT JACKET
# 2    281883711-071-2                               SUIT JACKET
# 3    323646471-802-2                       PADDED DENIM JACKET
# 4    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 7    315758723-401-2                             BOMBER JACKET
# 8    324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9    330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
# 10   323175653-803-2                        SOFT JEWEL SWEATER
#
#                                           description Seasonal Promotion  \
# 0   Varsity jacket with elastic collar and long sl...      Yes        No
# 1   Straight fit jacket made of dense stretch fabr...       No       Yes
# 2   Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3   Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 7   Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8   Wool and silk blend top. High collar and long ...       No       Yes
# 9   Oversized jacket. Notched lapel collar and lon...       No       Yes
# 10  Sweater made of soft touch fabric. Round neckl...       No       Yes
#
#        price  Sales Volume
# 0   $169.00         2608.0
# 1   $169.00         1524.0
# 2    $69.90         1764.0
# 3   $109.00          707.0
# 4    $59.90         2877.0
# 5    $59.90         2877.0
# 7   $169.00         1145.0
# 8    $49.90         1942.0
# 9   $159.00         2222.0
# 10   $39.90         2591.0

# %%
df.dropna(how='all').isnull().sum()
# Out:
# Product ID          0
# Release             0
# Product Position    0
# section             6
# terms               0
# sku                 0
# name                0
# description         4
# Seasonal            0
# Promotion           0
# price               0
# Sales Volume        0
# dtype: int64

# %%
# Getting rid of rows if there is any null
df.dropna(how='any').head(10)
# Out:
#     Product ID     Release Product Position section     terms  \
# 0     179801.0  10/21/2023   Front of Store     MAN   jackets
# 1     183243.0    7/1/2023   Front of Store     MAN   jackets
# 2     177771.0   1/22/2023          End-cap     MAN  t-shirts
# 4     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 7     178281.0    3/8/2024          End-cap     MAN   jackets
# 8     155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9     199233.0   1/15/2024            Aisle     MAN   jackets
# 10    181502.0   11/7/2023   Front of Store   WOMAN  sweaters
# 11    174708.0    3/5/2023   Front of Store     MAN  sweaters
#
#                  sku                                      name  \
# 0    311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1   328250627-251-46                               SUIT JACKET
# 2    281883711-071-2                               SUIT JACKET
# 4    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 7    315758723-401-2                             BOMBER JACKET
# 8    324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9    330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
# 10   323175653-803-2                        SOFT JEWEL SWEATER
# 11   317889153-700-3                 ABSTRACT JACQUARD SWEATER
#
#                                           description Seasonal Promotion  \
# 0   Varsity jacket with elastic collar and long sl...      Yes        No
# 1   Straight fit jacket made of dense stretch fabr...       No       Yes
# 2   Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 4   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 7   Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8   Wool and silk blend top. High collar and long ...       No       Yes
# 9   Oversized jacket. Notched lapel collar and lon...       No       Yes
# 10  Sweater made of soft touch fabric. Round neckl...       No       Yes
# 11  Full cut cotton knit sweater. Round neck and l...      Yes        No
#
#        price  Sales Volume
# 0   $169.00         2608.0
# 1   $169.00         1524.0
# 2    $69.90         1764.0
# 4    $59.90         2877.0
# 5    $59.90         2877.0
# 7   $169.00         1145.0
# 8    $49.90         1942.0
# 9   $159.00         2222.0
# 10   $39.90         2591.0
# 11   $59.90          529.0

# %%
df.dropna(how='any').isnull().sum()
# Out:
# Product ID          0
# Release             0
# Product Position    0
# section             0
# terms               0
# sku                 0
# name                0
# description         0
# Seasonal            0
# Promotion           0
# price               0
# Sales Volume        0
# dtype: int64

# %%
df = df.dropna(how='all')

# %% [markdown]
# ### 2. Fill in with non-null value/s
# 1. Forward Fill
# 2. Backward Fill
# 3. Replace with Constant Values
# 4. Mean/Median/Mode Imputation

# %%
df1 = zara.copy()

# %%
# Fill in with constant values
df1.fillna(value=0).head(10)
# Out:
#    Product ID     Release Product Position section     terms  \
# 0    179801.0  10/21/2023   Front of Store     MAN   jackets
# 1    183243.0    7/1/2023   Front of Store     MAN   jackets
# 2    177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3    171860.0    1/4/2023            Aisle       0  t-shirts
# 4    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 6         0.0           0                0       0         0
# 7    178281.0    3/8/2024          End-cap     MAN   jackets
# 8    155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9    199233.0   1/15/2024            Aisle     MAN   jackets
#
#                 sku                                      name  \
# 0   311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1  328250627-251-46                               SUIT JACKET
# 2   281883711-071-2                               SUIT JACKET
# 3   323646471-802-2                       PADDED DENIM JACKET
# 4   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 6                 0                                         0
# 7   315758723-401-2                             BOMBER JACKET
# 8   324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9   330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
# 2  Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3  Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 6                                                  0        0         0
# 7  Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8  Wool and silk blend top. High collar and long ...       No       Yes
# 9  Oversized jacket. Notched lapel collar and lon...       No       Yes
#
#       price  Sales Volume
# 0  $169.00         2608.0
# 1  $169.00         1524.0
# 2   $69.90         1764.0
# 3  $109.00          707.0
# 4   $59.90         2877.0
# 5   $59.90         2877.0
# 6         0           0.0
# 7  $169.00         1145.0
# 8   $49.90         1942.0
# 9  $159.00         2222.0

# %%
# Fill with constant values
df1.fillna('abc').head(10)
# Out:
#   Product ID     Release Product Position section     terms               sku  \
# 0   179801.0  10/21/2023   Front of Store     MAN   jackets   311307255-800-2
# 1   183243.0    7/1/2023   Front of Store     MAN   jackets  328250627-251-46
# 2   177771.0   1/22/2023          End-cap     MAN  t-shirts   281883711-071-2
# 3   171860.0    1/4/2023            Aisle     abc  t-shirts   323646471-802-2
# 4   166331.0    7/9/2023            Aisle   WOMAN  sweaters   324186867-642-2
# 5   166331.0    7/9/2023            Aisle   WOMAN  sweaters   324186867-642-2
# 6        abc         abc              abc     abc       abc               abc
# 7   178281.0    3/8/2024          End-cap     MAN   jackets   315758723-401-2
# 8   155848.0   4/24/2023          End-cap   WOMAN  sweaters   324597432-800-2
# 9   199233.0   1/15/2024            Aisle     MAN   jackets   330590505-500-2
#
#                                        name  \
# 0         CONTRASTING PATCHES BOMBER JACKET
# 1                               SUIT JACKET
# 2                               SUIT JACKET
# 3                       PADDED DENIM JACKET
# 4  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 6                                       abc
# 7                             BOMBER JACKET
# 8    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9         CONTRASTING PATCHES BOMBER JACKET
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
# 2  Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3  Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 6                                                abc      abc       abc
# 7  Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8  Wool and silk blend top. High collar and long ...       No       Yes
# 9  Oversized jacket. Notched lapel collar and lon...       No       Yes
#
#       price Sales Volume
# 0  $169.00        2608.0
# 1  $169.00        1524.0
# 2   $69.90        1764.0
# 3  $109.00         707.0
# 4   $59.90        2877.0
# 5   $59.90        2877.0
# 6       abc          abc
# 7  $169.00        1145.0
# 8   $49.90        1942.0
# 9  $159.00        2222.0

# %%
df1['section'].fillna('WOMAN').head(10)
# Out:
# 0      MAN
# 1      MAN
# 2      MAN
# 3    WOMAN
# 4    WOMAN
# 5    WOMAN
# 6    WOMAN
# 7      MAN
# 8    WOMAN
# 9      MAN
# Name: section, dtype: object

# %%
# Fill using ffill (get value of prev row)
df1.ffill().head(10)
# Out:
#    Product ID     Release Product Position section     terms  \
# 0    179801.0  10/21/2023   Front of Store     MAN   jackets
# 1    183243.0    7/1/2023   Front of Store     MAN   jackets
# 2    177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3    171860.0    1/4/2023            Aisle     MAN  t-shirts
# 4    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 6    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 7    178281.0    3/8/2024          End-cap     MAN   jackets
# 8    155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9    199233.0   1/15/2024            Aisle     MAN   jackets
#
#                 sku                                      name  \
# 0   311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1  328250627-251-46                               SUIT JACKET
# 2   281883711-071-2                               SUIT JACKET
# 3   323646471-802-2                       PADDED DENIM JACKET
# 4   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 6   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 7   315758723-401-2                             BOMBER JACKET
# 8   324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9   330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
# 2  Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3  Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 6  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 7  Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8  Wool and silk blend top. High collar and long ...       No       Yes
# 9  Oversized jacket. Notched lapel collar and lon...       No       Yes
#
#       price  Sales Volume
# 0  $169.00         2608.0
# 1  $169.00         1524.0
# 2   $69.90         1764.0
# 3  $109.00          707.0
# 4   $59.90         2877.0
# 5   $59.90         2877.0
# 6   $59.90         2877.0
# 7  $169.00         1145.0
# 8   $49.90         1942.0
# 9  $159.00         2222.0

# %%
# Fill with bfill (get value of next row)
df1.bfill().head(10)
# Out:
#    Product ID     Release Product Position section     terms  \
# 0    179801.0  10/21/2023   Front of Store     MAN   jackets
# 1    183243.0    7/1/2023   Front of Store     MAN   jackets
# 2    177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3    171860.0    1/4/2023            Aisle   WOMAN  t-shirts
# 4    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5    166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 6    178281.0    3/8/2024          End-cap     MAN   jackets
# 7    178281.0    3/8/2024          End-cap     MAN   jackets
# 8    155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9    199233.0   1/15/2024            Aisle     MAN   jackets
#
#                 sku                                      name  \
# 0   311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1  328250627-251-46                               SUIT JACKET
# 2   281883711-071-2                               SUIT JACKET
# 3   323646471-802-2                       PADDED DENIM JACKET
# 4   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 6   315758723-401-2                             BOMBER JACKET
# 7   315758723-401-2                             BOMBER JACKET
# 8   324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9   330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
# 2  Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3  Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 6  Varsity jacket. High collar and long sleeves. ...      Yes        No
# 7  Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8  Wool and silk blend top. High collar and long ...       No       Yes
# 9  Oversized jacket. Notched lapel collar and lon...       No       Yes
#
#       price  Sales Volume
# 0  $169.00         2608.0
# 1  $169.00         1524.0
# 2   $69.90         1764.0
# 3  $109.00          707.0
# 4   $59.90         2877.0
# 5   $59.90         2877.0
# 6  $169.00         1145.0
# 7  $169.00         1145.0
# 8   $49.90         1942.0
# 9  $159.00         2222.0

# %%
df = df.fillna(value='N/A')

# %%
df.head(10)
# Out:
#     Product ID     Release Product Position section     terms  \
# 0     179801.0  10/21/2023   Front of Store     MAN   jackets
# 1     183243.0    7/1/2023   Front of Store     MAN   jackets
# 2     177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3     171860.0    1/4/2023            Aisle     N/A  t-shirts
# 4     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 7     178281.0    3/8/2024          End-cap     MAN   jackets
# 8     155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9     199233.0   1/15/2024            Aisle     MAN   jackets
# 10    181502.0   11/7/2023   Front of Store   WOMAN  sweaters
#
#                  sku                                      name  \
# 0    311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1   328250627-251-46                               SUIT JACKET
# 2    281883711-071-2                               SUIT JACKET
# 3    323646471-802-2                       PADDED DENIM JACKET
# 4    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 7    315758723-401-2                             BOMBER JACKET
# 8    324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9    330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
# 10   323175653-803-2                        SOFT JEWEL SWEATER
#
#                                           description Seasonal Promotion  \
# 0   Varsity jacket with elastic collar and long sl...      Yes        No
# 1   Straight fit jacket made of dense stretch fabr...       No       Yes
# 2   Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3   Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 7   Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8   Wool and silk blend top. High collar and long ...       No       Yes
# 9   Oversized jacket. Notched lapel collar and lon...       No       Yes
# 10  Sweater made of soft touch fabric. Round neckl...       No       Yes
#
#        price  Sales Volume
# 0   $169.00         2608.0
# 1   $169.00         1524.0
# 2    $69.90         1764.0
# 3   $109.00          707.0
# 4    $59.90         2877.0
# 5    $59.90         2877.0
# 7   $169.00         1145.0
# 8    $49.90         1942.0
# 9   $159.00         2222.0
# 10   $39.90         2591.0

# %% [markdown]
# ## **Step 2: Removing Duplicates**

# %%
df.head(10)
# Out:
#     Product ID     Release Product Position section     terms  \
# 0     179801.0  10/21/2023   Front of Store     MAN   jackets
# 1     183243.0    7/1/2023   Front of Store     MAN   jackets
# 2     177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3     171860.0    1/4/2023            Aisle     NaN  t-shirts
# 4     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 5     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 7     178281.0    3/8/2024          End-cap     MAN   jackets
# 8     155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9     199233.0   1/15/2024            Aisle     MAN   jackets
# 10    181502.0   11/7/2023   Front of Store   WOMAN  sweaters
#
#                  sku                                      name  \
# 0    311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1   328250627-251-46                               SUIT JACKET
# 2    281883711-071-2                               SUIT JACKET
# 3    323646471-802-2                       PADDED DENIM JACKET
# 4    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 5    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 7    315758723-401-2                             BOMBER JACKET
# 8    324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9    330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
# 10   323175653-803-2                        SOFT JEWEL SWEATER
#
#                                           description Seasonal Promotion  \
# 0   Varsity jacket with elastic collar and long sl...      Yes        No
# 1   Straight fit jacket made of dense stretch fabr...       No       Yes
# 2   Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3   Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 5   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 7   Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8   Wool and silk blend top. High collar and long ...       No       Yes
# 9   Oversized jacket. Notched lapel collar and lon...       No       Yes
# 10  Sweater made of soft touch fabric. Round neckl...       No       Yes
#
#        price  Sales Volume
# 0   $169.00         2608.0
# 1   $169.00         1524.0
# 2    $69.90         1764.0
# 3   $109.00          707.0
# 4    $59.90         2877.0
# 5    $59.90         2877.0
# 7   $169.00         1145.0
# 8    $49.90         1942.0
# 9   $159.00         2222.0
# 10   $39.90         2591.0

# %%
df.shape
# Out:
# (261, 12)

# %%
# See counts of duplicated records
df.duplicated().sum()
# Out:
# 7

# %%
# View all duplicates keep='first' means see the next occurence
df.loc[df.duplicated(keep='last')]
# Out:
#      Product ID     Release Product Position section     terms  \
# 4      166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 40     182157.0    6/7/2023            Aisle     MAN   jackets
# 49     141434.0  12/10/2023   Front of Store     MAN   jackets
# 98     141904.0   8/23/2023          End-cap     MAN   jackets
# 103    197524.0    8/4/2023            Aisle     MAN   jackets
# 115    151396.0   3/17/2024   Front of Store     MAN   jackets
# 125    166345.0   3/15/2023            Aisle     MAN   jackets
#
#                   sku                                      name  \
# 4     324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 40   322972485-431-46                 SUIT JACKET IN 100% LINEN
# 49   311307610-400-39                FAUX LEATHER PUFFER JACKET
# 98    313845662-400-3                     JACQUARD DENIM JACKET
# 103   330590505-500-2                           PLAID OVERSHIRT
# 115   323134418-800-3                    CROPPED LEATHER JACKET
# 125  322929313-802-97                      HOODED KNIT CARDIGAN
#
#                                            description Seasonal Promotion  \
# 4    Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 40   Straight fit blazer made of linen. Notched lap...       No        No
# 49   Jacket with lightly padded interior. Rib colla...      Yes        No
# 98   Lapel collar jacket with long sleeves with but...      Yes       Yes
# 103  Relaxed fit overshirt. Lapel collar and long s...      Yes       Yes
# 115  Leather jacket. Cropped length. Lapel collar a...      Yes       Yes
# 125  Cotton knit jacket. Hooded collar and long sle...      Yes        No
#
#         price  Sales Volume
# 4     $59.90         2877.0
# 40   $159.00         2421.0
# 49    $39.90         2870.0
# 98   $109.00         1712.0
# 103   $49.90         2231.0
# 115  $439.00          729.0
# 125   $69.90         1135.0

# %%
# Remove all duplicates, keep the first occurence
df.drop_duplicates(keep='first').head(10)
# Out:
#     Product ID     Release Product Position section     terms  \
# 0     179801.0  10/21/2023   Front of Store     MAN   jackets
# 1     183243.0    7/1/2023   Front of Store     MAN   jackets
# 2     177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3     171860.0    1/4/2023            Aisle     NaN  t-shirts
# 4     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 7     178281.0    3/8/2024          End-cap     MAN   jackets
# 8     155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9     199233.0   1/15/2024            Aisle     MAN   jackets
# 10    181502.0   11/7/2023   Front of Store   WOMAN  sweaters
# 11    174708.0    3/5/2023   Front of Store     MAN  sweaters
#
#                  sku                                      name  \
# 0    311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1   328250627-251-46                               SUIT JACKET
# 2    281883711-071-2                               SUIT JACKET
# 3    323646471-802-2                       PADDED DENIM JACKET
# 4    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 7    315758723-401-2                             BOMBER JACKET
# 8    324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9    330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
# 10   323175653-803-2                        SOFT JEWEL SWEATER
# 11   317889153-700-3                 ABSTRACT JACQUARD SWEATER
#
#                                           description Seasonal Promotion  \
# 0   Varsity jacket with elastic collar and long sl...      Yes        No
# 1   Straight fit jacket made of dense stretch fabr...       No       Yes
# 2   Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3   Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 7   Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8   Wool and silk blend top. High collar and long ...       No       Yes
# 9   Oversized jacket. Notched lapel collar and lon...       No       Yes
# 10  Sweater made of soft touch fabric. Round neckl...       No       Yes
# 11  Full cut cotton knit sweater. Round neck and l...      Yes        No
#
#        price  Sales Volume
# 0   $169.00         2608.0
# 1   $169.00         1524.0
# 2    $69.90         1764.0
# 3   $109.00          707.0
# 4    $59.90         2877.0
# 7   $169.00         1145.0
# 8    $49.90         1942.0
# 9   $159.00         2222.0
# 10   $39.90         2591.0
# 11   $59.90          529.0

# %%
# Remove all duplicates, keep the last occurence
df.drop_duplicates(keep='last').head(10)
# Out:
#     Product ID     Release Product Position section     terms  \
# 0     179801.0  10/21/2023   Front of Store     MAN   jackets
# 1     183243.0    7/1/2023   Front of Store     MAN   jackets
# 2     177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3     171860.0    1/4/2023            Aisle     NaN  t-shirts
# 5     166331.0    7/9/2023            Aisle   WOMAN  sweaters
# 7     178281.0    3/8/2024          End-cap     MAN   jackets
# 8     155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9     199233.0   1/15/2024            Aisle     MAN   jackets
# 10    181502.0   11/7/2023   Front of Store   WOMAN  sweaters
# 11    174708.0    3/5/2023   Front of Store     MAN  sweaters
#
#                  sku                                      name  \
# 0    311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1   328250627-251-46                               SUIT JACKET
# 2    281883711-071-2                               SUIT JACKET
# 3    323646471-802-2                       PADDED DENIM JACKET
# 5    324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
# 7    315758723-401-2                             BOMBER JACKET
# 8    324597432-800-2    MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9    330590505-500-2         CONTRASTING PATCHES BOMBER JACKET
# 10   323175653-803-2                        SOFT JEWEL SWEATER
# 11   317889153-700-3                 ABSTRACT JACQUARD SWEATER
#
#                                           description Seasonal Promotion  \
# 0   Varsity jacket with elastic collar and long sl...      Yes        No
# 1   Straight fit jacket made of dense stretch fabr...       No       Yes
# 2   Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3   Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 5   Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
# 7   Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8   Wool and silk blend top. High collar and long ...       No       Yes
# 9   Oversized jacket. Notched lapel collar and lon...       No       Yes
# 10  Sweater made of soft touch fabric. Round neckl...       No       Yes
# 11  Full cut cotton knit sweater. Round neck and l...      Yes        No
#
#        price  Sales Volume
# 0   $169.00         2608.0
# 1   $169.00         1524.0
# 2    $69.90         1764.0
# 3   $109.00          707.0
# 5    $59.90         2877.0
# 7   $169.00         1145.0
# 8    $49.90         1942.0
# 9   $159.00         2222.0
# 10   $39.90         2591.0
# 11   $59.90          529.0

# %%
# Remove all duplicates, all occurence
df.drop_duplicates(keep=False).head(10)
# Out:
#     Product ID     Release Product Position section     terms  \
# 0     179801.0  10/21/2023   Front of Store     MAN   jackets
# 1     183243.0    7/1/2023   Front of Store     MAN   jackets
# 2     177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3     171860.0    1/4/2023            Aisle     NaN  t-shirts
# 7     178281.0    3/8/2024          End-cap     MAN   jackets
# 8     155848.0   4/24/2023          End-cap   WOMAN  sweaters
# 9     199233.0   1/15/2024            Aisle     MAN   jackets
# 10    181502.0   11/7/2023   Front of Store   WOMAN  sweaters
# 11    174708.0    3/5/2023   Front of Store     MAN  sweaters
# 12    175059.0   8/19/2023            Aisle     MAN   jackets
#
#                  sku                                    name  \
# 0    311307255-800-2       CONTRASTING PATCHES BOMBER JACKET
# 1   328250627-251-46                             SUIT JACKET
# 2    281883711-071-2                             SUIT JACKET
# 3    323646471-802-2                     PADDED DENIM JACKET
# 7    315758723-401-2                           BOMBER JACKET
# 8    324597432-800-2  MOCK NECK WOOL AND SILK BLEND KNIT TOP
# 9    330590505-500-2       CONTRASTING PATCHES BOMBER JACKET
# 10   323175653-803-2                      SOFT JEWEL SWEATER
# 11   317889153-700-3               ABSTRACT JACQUARD SWEATER
# 12   311292572-401-2               LIGHTWEIGHT BOMBER JACKET
#
#                                           description Seasonal Promotion  \
# 0   Varsity jacket with elastic collar and long sl...      Yes        No
# 1   Straight fit jacket made of dense stretch fabr...       No       Yes
# 2   Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3   Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 7   Varsity jacket. High collar and long sleeves. ...      Yes        No
# 8   Wool and silk blend top. High collar and long ...       No       Yes
# 9   Oversized jacket. Notched lapel collar and lon...       No       Yes
# 10  Sweater made of soft touch fabric. Round neckl...       No       Yes
# 11  Full cut cotton knit sweater. Round neck and l...      Yes        No
# 12  Lightweight jacket made of technical fabric. R...       No       Yes
#
#        price  Sales Volume
# 0   $169.00         2608.0
# 1   $169.00         1524.0
# 2    $69.90         1764.0
# 3   $109.00          707.0
# 7   $169.00         1145.0
# 8    $49.90         1942.0
# 9   $159.00         2222.0
# 10   $39.90         2591.0
# 11   $59.90          529.0
# 12   $49.90         2170.0

# %%
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## **Step 3: Add/Drop Columns**

# %%
df.to_csv('zara_cleaned.csv', index=False)

# %% [markdown]
# ##### **Drop** columns when it is irrelevant for the analysis, if it is causing redundancy, if it has too much null values

# %%
# Question: Which among the columns are not useful if we are to do a statistical analysis on this data?
df = df.drop('Description', axis='columns')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 274
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        254 non-null    object
#  1   Release           254 non-null    datetime64[ns]
#  2   Product Position  254 non-null    category
#  3   Section           254 non-null    object
#  4   Terms             254 non-null    object
#  5   SKU               254 non-null    object
#  6   Name              254 non-null    object
#  7   Seasonal          254 non-null    category
#  8   Promotion         254 non-null    category
#  9   Price             254 non-null    float64
#  10  Sales Volume      254 non-null    int32
# dtypes: category(3), datetime64[ns](1), float64(1), int32(1), object(5)
# memory usage: 26.1+ KB

# %% [markdown]
# ##### **Add** columns to add new features to our data. It can be a completely new data or something calculated based on present data.

# %%
# Different ways to add a column
zshort = pd.read_csv('zshort.csv')
zshort
# Out:
#   Product Position     Terms                                      Name
# 0   Front of Store   Jackets         Contrasting Patches Bomber Jacket
# 1   Front of Store   Jackets                               Suit Jacket
# 2          End-cap  T-Shirts                             Suit Jacket\t
# 3            Aisle  T-Shirts                     Padded Denim Jacket\t
# 4            Aisle  Sweaters  Asymmetrical Wool And Silk Blend Sweater
# 5          End-cap   Jackets                             Bomber Jacket
# 6          End-cap  Sweaters    Mock Neck Wool And Silk Blend Knit Top

# %%
zdf = zshort.copy()

# %%
# List method
Section = ['Man', 'Woman','Man','Man','Woman','Woman','Woman']
zdf['Section'] = Section

# %%
zdf
# Out:
#   Product Position     Terms                                      Name Section
# 0   Front of Store   Jackets         Contrasting Patches Bomber Jacket     Man
# 1   Front of Store   Jackets                               Suit Jacket   Woman
# 2          End-cap  T-Shirts                             Suit Jacket\t     Man
# 3            Aisle  T-Shirts                     Padded Denim Jacket\t     Man
# 4            Aisle  Sweaters  Asymmetrical Wool And Silk Blend Sweater   Woman
# 5          End-cap   Jackets                             Bomber Jacket   Woman
# 6          End-cap  Sweaters    Mock Neck Wool And Silk Blend Knit Top   Woman

# %%
# Default values method
zdf1 = zshort.copy()
zdf1['Section'] = ["Woman"]*len(zdf1)

# %%
zdf1
# Out:
#   Product Position     Terms                                      Name Section
# 0   Front of Store   Jackets         Contrasting Patches Bomber Jacket   Woman
# 1   Front of Store   Jackets                               Suit Jacket   Woman
# 2          End-cap  T-Shirts                             Suit Jacket\t   Woman
# 3            Aisle  T-Shirts                     Padded Denim Jacket\t   Woman
# 4            Aisle  Sweaters  Asymmetrical Wool And Silk Blend Sweater   Woman
# 5          End-cap   Jackets                             Bomber Jacket   Woman
# 6          End-cap  Sweaters    Mock Neck Wool And Silk Blend Knit Top   Woman

# %%
# Insert at a specific position
zdf2 = zshort.copy()
zdf2.insert(0, "Brand", ["Zara"]*len(zdf2))

# %%
zdf2
# Out:
#   Brand Product Position     Terms                                      Name
# 0  Zara   Front of Store   Jackets         Contrasting Patches Bomber Jacket
# 1  Zara   Front of Store   Jackets                               Suit Jacket
# 2  Zara          End-cap  T-Shirts                             Suit Jacket\t
# 3  Zara            Aisle  T-Shirts                     Padded Denim Jacket\t
# 4  Zara            Aisle  Sweaters  Asymmetrical Wool And Silk Blend Sweater
# 5  Zara          End-cap   Jackets                             Bomber Jacket
# 6  Zara          End-cap  Sweaters    Mock Neck Wool And Silk Blend Knit Top

# %%
df.head()
# Out:
#   Product ID    Release Product Position Section     Terms               SKU  \
# 0   179801.0 2023-10-21   Front of Store     Man   Jackets   311307255-800-2
# 1   183243.0 2023-07-01   Front of Store     Man   Jackets  328250627-251-46
# 2   177771.0 2023-01-22          End-cap     Man  T-Shirts   281883711-071-2
# 3   171860.0 2023-01-04            Aisle     N/A  T-Shirts   323646471-802-2
# 4   166331.0 2023-07-09            Aisle   Woman  Sweaters   324186867-642-2
#
#                                        Name Seasonal Promotion  Price  \
# 0         Contrasting Patches Bomber Jacket      Yes        No  169.0
# 1                               Suit Jacket       No       Yes  169.0
# 2                               Suit Jacket      Yes       Yes   69.9
# 3                       Padded Denim Jacket       No       Yes  109.0
# 4  Asymmetrical Wool And Silk Blend Sweater      Yes       Yes   59.9
#
#    Sales Volume
# 0          2608
# 1          1524
# 2          1764
# 3           707
# 4          2877

# %%
# Derived from other data
df['Total Sales'] = df['Price']*df['Sales Volume']

# %%
df.head()
# Out:
#   Product ID    Release Product Position Section     Terms               SKU  \
# 0   179801.0 2023-10-21   Front of Store     Man   Jackets   311307255-800-2
# 1   183243.0 2023-07-01   Front of Store     Man   Jackets  328250627-251-46
# 2   177771.0 2023-01-22          End-cap     Man  T-Shirts   281883711-071-2
# 3   171860.0 2023-01-04            Aisle     N/A  T-Shirts   323646471-802-2
# 4   166331.0 2023-07-09            Aisle   Woman  Sweaters   324186867-642-2
#
#                                        Name Seasonal Promotion  Price  \
# 0         Contrasting Patches Bomber Jacket      Yes        No  169.0
# 1                               Suit Jacket       No       Yes  169.0
# 2                               Suit Jacket      Yes       Yes   69.9
# 3                       Padded Denim Jacket       No       Yes  109.0
# 4  Asymmetrical Wool And Silk Blend Sweater      Yes       Yes   59.9
#
#    Sales Volume  Total Sales
# 0          2608     440752.0
# 1          1524     257556.0
# 2          1764     123303.6
# 3           707      77063.0
# 4          2877     172332.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        254 non-null    object
#  1   Release           254 non-null    datetime64[ns]
#  2   Product Position  254 non-null    category
#  3   Section           254 non-null    object
#  4   Terms             254 non-null    object
#  5   SKU               254 non-null    object
#  6   Name              254 non-null    object
#  7   Seasonal          254 non-null    category
#  8   Promotion         254 non-null    category
#  9   Price             254 non-null    float64
#  10  Sales Volume      254 non-null    int32
#  11  Total Sales       254 non-null    float64
# dtypes: category(3), datetime64[ns](1), float64(2), int32(1), object(5)
# memory usage: 28.1+ KB

# %%
df['Year Released'] = df['Release'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261 entries, 0 to 274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Id        261 non-null    object
#  1   Release           261 non-null    datetime64[ns]
#  2   Product Position  261 non-null    category
#  3   Section           261 non-null    object
#  4   Terms             261 non-null    object
#  5   Sku               261 non-null    object
#  6   Name              261 non-null    object
#  7   Description       261 non-null    object
#  8   Seasonal          261 non-null    category
#  9   Promotion         261 non-null    category
#  10  Price             261 non-null    float64
#  11  Sales Volume      261 non-null    float64
# dtypes: category(3), datetime64[ns](1), float64(2), object(6)
# memory usage: 29.6+ KB

# %%
df.to_csv('zara_cleaned.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        254 non-null    object
#  1   Release           254 non-null    datetime64[ns]
#  2   Product Position  254 non-null    category
#  3   Section           248 non-null    object
#  4   Terms             254 non-null    object
#  5   SKU               254 non-null    object
#  6   Name              254 non-null    object
#  7   Description       250 non-null    object
#  8   Seasonal          254 non-null    category
#  9   Promotion         254 non-null    category
#  10  Price             254 non-null    float64
#  11  Sales Volume      254 non-null    int32
# dtypes: category(3), datetime64[ns](1), float64(1), int32(1), object(6)
# memory usage: 28.1+ KB

# %%
df.head(1)
# Out:
#   Product ID    Release Product Position Section    Terms              SKU  \
# 0   179801.0 2023-10-21   Front of Store     Man  Jackets  311307255-800-2
#
#                                 Name  \
# 0  Contrasting Patches Bomber Jacket
#
#                                          Description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
#
#    Price  Sales Volume
# 0  169.0          2608

# %%
# We can also change the cases/names of columns
df = df.rename(columns={'Product Id':'Product ID', 'Url':'URL', 'Sku': 'SKU'})

# %% [markdown]
# ## **Step 4: Fix Data Types**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        254 non-null    float64
#  1   Release           254 non-null    object
#  2   Product Position  254 non-null    object
#  3   section           248 non-null    object
#  4   terms             254 non-null    object
#  5   sku               254 non-null    object
#  6   name              254 non-null    object
#  7   description       250 non-null    object
#  8   Seasonal          254 non-null    object
#  9   Promotion         254 non-null    object
#  10  price             254 non-null    object
#  11  Sales Volume      254 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 25.8+ KB

# %%
df.head(5)
# Out:
#    Product ID     Release Product Position section     terms  \
# 0    179801.0  10/21/2023   Front of Store     MAN   jackets
# 1    183243.0    7/1/2023   Front of Store     MAN   jackets
# 2    177771.0   1/22/2023          End-cap     MAN  t-shirts
# 3    171860.0    1/4/2023            Aisle     NaN  t-shirts
# 4    166331.0    7/9/2023            Aisle   WOMAN  sweaters
#
#                 sku                                      name  \
# 0   311307255-800-2         CONTRASTING PATCHES BOMBER JACKET
# 1  328250627-251-46                               SUIT JACKET
# 2   281883711-071-2                               SUIT JACKET
# 3   323646471-802-2                       PADDED DENIM JACKET
# 4   324186867-642-2  ASYMMETRICAL WOOL AND SILK BLEND SWEATER
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
# 2  Jacket with lightly padded interior. Corduroy ...      Yes       Yes
# 3  Slightly cropped denim jacket. Lapel collar an...       No       Yes
# 4  Wool and silk blend sweater. Asymmetric neckli...      Yes       Yes
#
#       price  Sales Volume
# 0  $169.00         2608.0
# 1  $169.00         1524.0
# 2   $69.90         1764.0
# 3  $109.00          707.0
# 4   $59.90         2877.0

# %%
# Convert date columns to datetime YYYY-MM-DD
# by default detects YYYY-MM-DD format
df['Release'] = pd.to_datetime(df['Release'], dayfirst=True)
# Out:
# <ipython-input-35-d12f7a4005f7>:3: UserWarning: Parsing dates in %m/%d/%Y format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['Release'] = pd.to_datetime(df['Release'], dayfirst=True)

# %%
df['Release'].head(10)
# Out:
# 0    2023-10-21
# 1    2023-07-01
# 2    2023-01-22
# 3    2023-01-04
# 4    2023-07-09
# 7    2024-03-08
# 8    2023-04-24
# 9    2024-01-15
# 10   2023-11-07
# 11   2023-03-05
# Name: Release, dtype: datetime64[ns]

# %% [markdown]
# #### pd.to_datetime & strftime

# %%
# October 12 2012
dfirst = '10/12/2012'
mfirst = '12/10/2012'
fulldate = 'October 12, 2012'

# %%
pd.to_datetime(fulldate)
# Out:
# Timestamp('2012-10-12 00:00:00')

# %%
dfirst = pd.to_datetime(dfirst, dayfirst=True)
dfirst.strftime('%B %d, %Y')
# Out:
# 'December 10, 2012'

# %% [markdown]
# #### Cont.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        254 non-null    float64
#  1   Release           254 non-null    datetime64[ns]
#  2   Product Position  254 non-null    object
#  3   section           248 non-null    object
#  4   terms             254 non-null    object
#  5   sku               254 non-null    object
#  6   name              254 non-null    object
#  7   description       250 non-null    object
#  8   Seasonal          254 non-null    object
#  9   Promotion         254 non-null    object
#  10  price             254 non-null    object
#  11  Sales Volume      254 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 33.9+ KB

# %%
df['Product ID'] = df['Product ID'].astype(str)

# %%
# Convert numeric values to strings
df['Sales Volume'] = df['Sales Volume'].astype(str)

# %%
# Convert string to numeric
df['Sales Volume'] = pd.to_numeric(df['Sales Volume'])

# %% [markdown]
# * If you have a string you strictly require to be converted to numeric, use .to_numeric() method.
# * With .to_numeric(errors='coerce'), it will force convert. make nonnumeric = NaN.
# * If you already have numeric dtypes (int8|16|32|64,float64,boolean)
# you can convert it to another "numeric" dtype using.astype() method.
# * .astype() wont apply to object types being converted to numerical

# %%
df['Sales Volume'] = df['Sales Volume'].astype('int32')

# %%
df= df.astype({'Product ID': 'str','Sales Volume':'int32'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        254 non-null    object
#  1   Release           254 non-null    datetime64[ns]
#  2   Product Position  254 non-null    object
#  3   section           248 non-null    object
#  4   terms             254 non-null    object
#  5   sku               254 non-null    object
#  6   name              254 non-null    object
#  7   description       250 non-null    object
#  8   Seasonal          254 non-null    object
#  9   Promotion         254 non-null    object
#  10  price             254 non-null    object
#  11  Sales Volume      254 non-null    int32
# dtypes: datetime64[ns](1), int32(1), object(10)
# memory usage: 32.9+ KB

# %%
# df['price'] = pd.to_numeric(df['price'])

# %%
# Replace chars
df['price'] = df['price'].str.replace('$', '')

# %%
df['price'] = pd.to_numeric(df['price'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        254 non-null    object
#  1   Release           254 non-null    datetime64[ns]
#  2   Product Position  254 non-null    object
#  3   section           248 non-null    object
#  4   terms             254 non-null    object
#  5   sku               254 non-null    object
#  6   name              254 non-null    object
#  7   description       250 non-null    object
#  8   Seasonal          254 non-null    object
#  9   Promotion         254 non-null    object
#  10  price             254 non-null    float64
#  11  Sales Volume      254 non-null    int32
# dtypes: datetime64[ns](1), float64(1), int32(1), object(9)
# memory usage: 32.9+ KB

# %%
df.nunique()
# Out:
# Product ID          252
# Release             192
# Product Position      3
# section               2
# terms                 5
# sku                 228
# name                195
# description         219
# Seasonal              2
# Promotion             2
# price                27
# Sales Volume        234
# dtype: int64

# %%
# Convert to category type
df['Seasonal'] = df['Seasonal'].astype("category")
df['Seasonal'].cat.categories
# Out:
# Index(['No', 'Yes'], dtype='object')

# %%
df['Promotion'] = df['Promotion'].astype("category")
df['Promotion'].cat.categories
# Out:
# Index(['No', 'Yes'], dtype='object')

# %%
df['Product Position'] = df['Product Position'].astype("category")
df['Product Position'].cat.categories
# Out:
# Index(['Aisle', 'End-cap', 'Front of Store'], dtype='object')

# %%
df.head(3)
# Out:
#   Product ID    Release Product Position section     terms               sku  \
# 0   179801.0 2023-10-21   Front of Store     MAN   jackets   311307255-800-2
# 1   183243.0 2023-07-01   Front of Store     MAN   jackets  328250627-251-46
# 2   177771.0 2023-01-22          End-cap     MAN  t-shirts   281883711-071-2
#
#                                 name  \
# 0  CONTRASTING PATCHES BOMBER JACKET
# 1                        SUIT JACKET
# 2                        SUIT JACKET
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
# 2  Jacket with lightly padded interior. Corduroy ...      Yes       Yes
#
#    price  Sales Volume
# 0  169.0          2608
# 1  169.0          1524
# 2   69.9          1764

# %%
# Check changes in memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        254 non-null    object
#  1   Release           254 non-null    datetime64[ns]
#  2   Product Position  254 non-null    category
#  3   section           248 non-null    object
#  4   terms             254 non-null    object
#  5   sku               254 non-null    object
#  6   name              254 non-null    object
#  7   description       250 non-null    object
#  8   Seasonal          254 non-null    category
#  9   Promotion         254 non-null    category
#  10  price             254 non-null    float64
#  11  Sales Volume      254 non-null    int32
# dtypes: category(3), datetime64[ns](1), float64(1), int32(1), object(6)
# memory usage: 28.1+ KB

# %% [markdown]
# ## **Step 5: Clean Text Data**
# Common Issues with Text Data
# 1. Different Formats and Cases
# 2. Different Spellings
# 3. Unnecessary elements (whitespaces, symbols)

# %%
df.head(1)
# Out:
#   Product ID    Release Product Position section    terms              sku  \
# 0   179801.0 2023-10-21   Front of Store     MAN  jackets  311307255-800-2
#
#                                 name  \
# 0  CONTRASTING PATCHES BOMBER JACKET
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
#
#    price  Sales Volume
# 0  169.0          2608

# %%
df['name'] = df['name'].str.title()
df['section'] = df['section'].str.title()
df['terms'] = df['terms'].str.title()
df.head(2)
# Out:
#   Product ID    Release Product Position section    terms               sku  \
# 0   179801.0 2023-10-21   Front of Store     Man  Jackets   311307255-800-2
# 1   183243.0 2023-07-01   Front of Store     Man  Jackets  328250627-251-46
#
#                                 name  \
# 0  Contrasting Patches Bomber Jacket
# 1                        Suit Jacket
#
#                                          description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
# 1  Straight fit jacket made of dense stretch fabr...       No       Yes
#
#    price  Sales Volume
# 0  169.0          2608
# 1  169.0          1524

# %%
df = df.rename(columns=str.title)

# %%
df.head(1)
# Out:
#   Product Id    Release Product Position Section    Terms              Sku  \
# 0   179801.0 2023-10-21   Front of Store     Man  Jackets  311307255-800-2
#
#                                 Name  \
# 0  Contrasting Patches Bomber Jacket
#
#                                          Description Seasonal Promotion  \
# 0  Varsity jacket with elastic collar and long sl...      Yes        No
#
#    Price  Sales Volume
# 0  169.0          2608
